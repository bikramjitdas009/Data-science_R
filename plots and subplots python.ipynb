# %%
##install and then import matplotlib

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(16,3))

# %%
import numpy as np

# %%
x = [-3, 5, 7]
y = [10, 2, 5]

# %%
fig = plt.figure(figsize=(15,3))

# %%
plt.plot(x, y)

# %%
plt.plot(x, y)
plt.xlim(-7, 13)
plt.ylim(0, 12)
plt.xlabel('X Axis')
plt.ylabel('Y axis')
plt.title('Line Plot')
plt.suptitle('Sales graph', size=20, y=1.03)
# Out:
# Text(0.5, 1.03, 'Sales graph')

# %%
#fig.get_size_inches()
fig.set_size_inches(14, 4)
fig, axs = plt.subplots(nrows=1, ncols=1)
fig

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt



mtcars = pd.read_csv("D:\\Datasets\\mtcars.csv")

# %%
mtcars.columns
# Out:
# Index(['mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear',
#        'carb'],
#       dtype='object')

# %%
summary(mtcars)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-e1d257a07288> in <module>
# ----> 1 summary(mtcars)
#
# NameError: name 'summary' is not defined
